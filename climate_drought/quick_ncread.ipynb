# %%
import xarray as xr

fname = '../output/soil_water_20200101-20221231_52.5_16.0.nc'

# %%
ds = xr.open_dataset(fname)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 3, latitude: 3, expver: 2, time: 456)
# Coordinates:
#   * longitude  (longitude) float32 15.9 16.0 16.1
#   * latitude   (latitude) float32 52.6 52.5 52.4
#   * expver     (expver) int32 1 5
#   * time       (time) datetime64[ns] 1985-01-01 1985-02-01 ... 2022-12-01
# Data variables:
#     swvl4      (time, expver, latitude, longitude) float32 ...
#     swvl1      (time, expver, latitude, longitude) float32 ...
#     swvl3      (time, expver, latitude, longitude) float32 ...
#     swvl2      (time, expver, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-03-24 16:50:42 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 3, latitude: 3, expver: 2, time: 456)
# Coordinates:
#   * longitude  (longitude) float32 15.9 16.0 16.1
#   * latitude   (latitude) float32 52.6 52.5 52.4
#   * expver     (expver) int32 1 5
#   * time       (time) datetime64[ns] 1985-01-01 1985-02-01 ... 2022-12-01
# Data variables:
#     swvl4      (time, expver, latitude, longitude) float32 ...
#     swvl1      (time, expver, latitude, longitude) float32 ...
#     swvl3      (time, expver, latitude, longitude) float32 ...
#     swvl2      (time, expver, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-03-24 16:50:42 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
Sdate = '19850101'
Edate = '20221231'

# %%
import utils
dates = utils.daterange(Sdate, Edate, 0)
dates[0]
# Out:
# '19850101'

# %%
from datetime import date
date_list = []
for indate in dates:
    yyyy = int(indate[0:4])
    mm = int(indate[4:6])
    dd = int(indate[6:8])
    date_list.append(date(yyyy,mm,dd))
date_list[0]
# Out:
# datetime.date(1985, 1, 1)
